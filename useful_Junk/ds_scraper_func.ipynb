# %%
import requests
from selenium import webdriver
from bs4 import BeautifulSoup as bs
import time
import pandas as pd

# %% [markdown]
# ##### Note that keyword case shoul be in kebab case ie. (kebab-case)

# %%
def urlGen(keyWord, pageNum):
    return "https://www.naukri.com/" + str(keyWord) + "-jobs-" + str(pageNum)

# %%
url = urlGen("data-science", 1)
print(url)
# Out:
# https://www.naukri.com/data-science-jobs-1

# %%
driver = webdriver.Chrome(".\\chromedriver.exe")
driver.get(url)

time.sleep(3)

soup = bs(driver.page_source, 'html5lib')

print(soup.prettify())

driver.close()
# Out:
# <html lang="en">
#  <head>
#   <title>
#    Data Scientist Jobs, 13836 Data Scientist Openings - Naukri.com
#   </title>
#   <meta content="Apply To 13836 Data Scientist Jobs On Naukri.com, India's No.1 Job Portal. Explore Data Scientist Openings In Your Desired Locations Now!" name="description"/>
#   <link href="android-app://naukriApp.appModules.login/https/www.naukri.com/data-scientist-jobs" rel="alternate"/>
#   <link href="https://www.naukri.com/data-scientist-jobs" rel="canonical"/>
#   <meta content="jobsearch" name="atdlayout"/>
#   <meta content="ALL" name="robots"/>
#   <meta content="Jobs &amp; Career: Job Search, Apply Jobs, Post Jobs" name="classification"/>
#   <meta content="no-cache" name="pragma"/>
#   <meta content="general" name="rating"/>
#   <meta content="1 day" name="revisit-after"/>
#   <meta content="GLOBAL" name="distribution"/>
#   <meta content="document" name="resource-type"/>
#   <meta content="www.naukri.com" name="author"/>
# ...

# %%
df = pd.DataFrame(columns=['Company','Job Count'])

# %%
job_elems = results.find('span',class_='grey-text lH20 fleft ml-8 txtLbl')
print(job_elems)
# Out:
# None
